# %%
# !pip install openai

# %%
# set open ai key
from openai import OpenAI
import os

with open('token.txt', 'r') as file:
  os.environ["OPENAI_API_KEY"] = file.read().strip()

openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
# audio 파일 음성 추출
client = OpenAI()

audio_file = open("voice_audio.mp3","rb")
transcription = client.audio.transcriptions.create(
  model="whisper-1",
  file=audio_file,
  response_format="text"
)

print("Done")
# Out:
# Done

# %%
# 내용 확인
print(transcription)
# Out:
# 오늘 아침에 커피 마시다가 거울 속 나랑 눈 마주쳤는데 우리 둘 다 출근하기 싫어 보이더라

# %%
# audio 파일 음성 추출 후 영어로 번역
translation = client.audio.translations.create(
    model="whisper-1",
  file=audio_file
)

print(translation.text)
# Out:
# I was drinking coffee this morning and I made eye contact with myself in the mirror. We both looked like we didn't want to go to work.

# %%
# 반대로 오디오 파일 만들기
speech_file_path = "speech_output.mp3"
response = client.audio.speech.create(
    model="tts-1",
  voice="alloy",
  input=transcription
)

response.stream_to_file(speech_file_path)
# Out:
# /tmp/ipython-input-3746270718.py:8: DeprecationWarning: Due to a bug, this method doesn't actually stream the response content, `.with_streaming_response.method()` should be used instead
#   response.stream_to_file(speech_file_path)

# %%
# audio 파일 재생
from IPython.display import Audio, display
Audio("speech_output.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
